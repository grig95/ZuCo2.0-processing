# %%
import numpy as np
import pandas as pd
import multiprocessing as mp
import matplotlib.pyplot as plt
import os
import mne
from wordfreq import word_frequency
from wordfreq import zipf_frequency
import re

from commons import normalize_word

from reader import EXTRACTED_DATA_PATH
from reader import EEG_CHANNEL_COUNT
from reader import MISSING_DATA_SYMBOL
from reader import EEG_FEATURES
from reader import ET_FEATURES

from reader import get_subjects_list

from eeg_plotter import MISSING_CHANNELS
from eeg_plotter import LANGUAGE_CHANNELS
from eeg_plotter import TRT_RANGES

from eeg_plotter import device_channel_to_data_channel
from eeg_plotter import channel_fill
from eeg_plotter import eeg_data_pad_to_len
from eeg_plotter import get_evoked_for_eeg_data
from eeg_plotter import get_raw_word_eeg
from eeg_plotter import get_raw_word_eeg_mean

def helper_get_word_mean_eeg(word_df, padding = 'mean'):
    '''
    Takes in a dataframe containing the 'task', 'sentence_id', 'word_idx' columnns
    corresponding to a single word (perhaps accross different sentences and subjects). It reads their eeg data,
    padds shorter appearences with either 0 or their mean to match the longest one and returns their mean.
    '''
    eeg_data = []
    maxlen = 0
    for appearence in word_df.itertuples(index=False):
        for subject in get_subjects_list():
            eeg_data.append( get_raw_word_eeg( (appearence[0], subject, appearence[1], appearence[2]) ) )
            if eeg_data[-1] is None:
                eeg_data.pop()
            else:
                maxlen = max(maxlen, eeg_data[-1].shape[0])
    if len(eeg_data) == 0:
        return None
    for i in range(len(eeg_data)):
        eeg_data[i] = eeg_data_pad_to_len(eeg_data[i], maxlen, padding)
    return np.mean( np.array(eeg_data), axis=0 )

# %%
# Get a frequency ordered list of nouns
# PLease also choose a task:
task = 'NR'
pos_tags_src = 'nltk'
df = pd.read_csv(f'{EXTRACTED_DATA_PATH}extracted_data_{task}/pos_tags/{pos_tags_src}.tsv', sep='\t', keep_default_na=False)
nn_df = df[ (df['part_of_speech'].isin(['NN', 'NNS'])) ] ['content']
nn_df = pd.unique( nn_df.apply(normalize_word) )
ordered_nouns = list(reversed( sorted( [(zipf_frequency(w, 'en'), w) for w in nn_df] ) ))
ordered_nouns
# Out:
# [(7.73, 'the'),
#  (7.41, 'and'),
#  (7.27, 'in'),
#  (6.82, 'this'),
#  (6.47, 'one'),
#  (6.3, 'her'),
#  (6.29, 'time'),
#  (6.26, 'she'),
#  (6.25, 'people'),
#  (6.12, 'only'),
#  (6.11, 'him'),
#  (6.04, 'back'),
#  (5.98, 'may'),
#  (5.96, 'years'),
#  (5.96, 'year'),
#  (5.96, 'work'),
#  (5.89, 'world'),
#  (5.89, 'life'),
#  (5.82, 'man'),
#  (5.81, 'home'),
#  (5.78, 'part'),
#  (5.75, 'help'),
#  (5.72, 'thing'),
#  (5.72, 'game'),
#  (5.71, 'school'),
#  (5.71, 'place'),
#  (5.7, 'again'),
#  (5.68, 'show'),
#  (5.68, 'end'),
#  (5.67, 'team'),
#  (5.66, 'family'),
#  (5.64, 'money'),
#  (5.63, 'second'),
#  (5.62, 'number'),
#  (5.61, 'name'),
#  (5.61, 'days'),
#  (5.61, 'city'),
#  (5.6, 'company'),
#  (5.57, 'group'),
#  (5.56, 'times'),
#  (5.56, 'start'),
#  (5.56, 'business'),
#  (5.55, 'person'),
#  (5.55, 'anything'),
#  (5.54, 'point'),
#  (5.54, 'change'),
#  (5.52, 'states'),
#  (5.52, 'power'),
#  (5.52, 'music'),
#  (5.52, 'including'),
#  (5.51, 'men'),
#  (5.51, 'head'),
#  (5.5, 'side'),
#  (5.5, 'job'),
#  (5.49, 'service'),
#  (5.49, 'later'),
#  (5.48, 'season'),
#  (5.48, 'country'),
#  (5.47, 'children'),
#  (5.46, 'war'),
#  (5.46, 'law'),
#  (5.46, 'area'),
#  (5.45, 'working'),
#  (5.45, 'story'),
#  (5.45, 'president'),
#  (5.44, 'games'),
#  (5.44, 'course'),
#  (5.43, 'friends'),
#  (5.43, 'book'),
#  (5.42, 'others'),
#  (5.41, 'level'),
#  (5.41, 'half'),
#  (5.4, 'office'),
#  (5.4, 'food'),
#  (5.4, 'death'),
#  (5.4, 'control'),
#  (5.4, 'body'),
#  (5.39, 'university'),
#  (5.39, 'research'),
#  (5.39, 'history'),
#  (5.38, 'girl'),
#  (5.37, 'playing'),
#  (5.37, 'hit'),
#  (5.37, 'friend'),
#  (5.37, 'air'),
#  (5.36, 'class'),
#  (5.35, 'series'),
#  (5.35, 'months'),
#  (5.35, 'members'),
#  (5.33, 'police'),
#  (5.33, 'c'),
#  (5.32, 'reason'),
#  (5.32, 'deal'),
#  (5.32, 'age'),
#  (5.31, 'heart'),
#  (5.31, 'form'),
#  (5.31, 'development'),
#  (5.3, 'major'),
#  (5.3, 'child'),
#  (5.29, 'west'),
#  (5.29, 'six'),
#  (5.29, 'play-by-play'),
#  (5.28, 'son'),
#  (5.28, 'list'),
#  (5.28, 'education'),
#  (5.27, 'program'),
#  (5.27, 'experience'),
#  (5.27, 'example'),
#  (5.27, 'college'),
#  (5.26, "she's"),
#  (5.26, 'father'),
#  (5.26, 'best-known'),
#  (5.25, 'words'),
#  (5.25, 'month'),
#  (5.24, 'town'),
#  (5.24, 'mother'),
#  (5.23, 'wife'),
#  (5.23, 'summer'),
#  (5.23, 'rest'),
#  (5.21, 'record'),
#  (5.21, 'position'),
#  (5.21, 'period'),
#  (5.21, 'parents'),
#  (5.21, 'account'),
#  (5.2, 'tv'),
#  (5.2, 'security'),
#  (5.2, 'film'),
#  (5.19, 'weeks'),
#  (5.19, 'star'),
#  (5.19, 'player'),
#  (5.19, 'issues'),
#  (5.19, 'industry'),
#  (5.19, 'dead'),
#  (5.19, 'center'),
#  (5.18, 'member'),
#  (5.17, 'society'),
#  (5.17, 're-make'),
#  (5.17, 'policy'),
#  (5.17, 'interest'),
#  (5.17, 'boy'),
#  (5.16, 'role'),
#  (5.16, 'performance'),
#  (5.16, 'movie'),
#  (5.16, 'church'),
#  (5.16, 'bank'),
#  (5.15, 'questions'),
#  (5.15, 'director'),
#  (5.15, 'books'),
#  (5.15, 'bill'),
#  (5.15, 'areas'),
#  (5.14, 'round'),
#  (5.14, 'production'),
#  (5.14, 'lives'),
#  (5.14, 'evidence'),
#  (5.13, 'picture'),
#  (5.13, 'blue'),
#  (5.12, 'trade'),
#  (5.12, 'science'),
#  (5.12, 'range'),
#  (5.12, 'page'),
#  (5.11, 'vote'),
#  (5.11, 'style'),
#  (5.08, 'staff'),
#  (5.09, 'decision'),
#  (5.09, 'poor'),
#  (5.09, 'release'),
#  (5.1, 'language'),
#  (5.1, 'oil'),
#  (5.1, 'title'),
#  (5.11, 'attention'),
#  (5.11, 'brother'),
#  (5.11, 'chief'),
#  (5.11, 'football'),
#  (5.11, 'style'),
#  (5.11, 'vote'),
#  (5.12, 'page'),
#  (5.12, 'range'),
#  (5.12, 'science'),
#  (5.12, 'trade'),
#  (5.13, 'blue'),
#  (5.13, 'picture'),
#  (5.14, 'evidence'),
#  (5.14, 'lives'),
#  (5.14, 'production'),
#  (5.14, 'round'),
#  (5.15, 'areas'),
#  (5.15, 'bill'),
#  (5.15, 'books'),
#  (5.15, 'director'),
#  (5.15, 'questions'),
#  (5.16, 'bank'),
#  (5.16, 'church'),
#  (5.16, 'movie'),
#  (5.16, 'performance'),
#  (5.16, 'role'),
#  (5.17, 'boy'),
#  (5.17, 'interest'),
#  (5.17, 'policy'),
#  (5.17, 're-make'),
#  (5.17, 'society'),
#  (5.18, 'member'),
#  (5.19, 'center'),
#  (5.19, 'dead'),
#  (5.19, 'industry'),
#  (5.19, 'issues'),
#  (5.19, 'player'),
#  (5.19, 'star'),
#  (5.19, 'weeks'),
#  (5.2, 'film'),
#  (5.2, 'security'),
#  (5.2, 'tv'),
#  (5.21, 'account'),
#  (5.21, 'parents'),
#  (5.21, 'period'),
#  (5.21, 'position'),
#  (5.21, 'record'),
#  (5.23, 'rest'),
#  (5.23, 'summer'),
#  (5.23, 'wife'),
#  (5.24, 'mother'),
#  (5.24, 'town'),
#  (5.25, 'month'),
#  (5.25, 'words'),
#  (5.26, 'best-known'),
#  (5.26, 'father'),
#  (5.26, "she's"),
#  (5.27, 'college'),
#  (5.27, 'example'),
#  (5.27, 'experience'),
#  (5.27, 'program'),
#  (5.28, 'education'),
#  (5.28, 'list'),
#  (5.28, 'son'),
#  (5.29, 'play-by-play'),
#  (5.29, 'six'),
#  (5.29, 'west'),
#  (5.3, 'child'),
#  (5.3, 'major'),
#  (5.31, 'development'),
#  (5.31, 'form'),
#  (5.31, 'heart'),
#  (5.32, 'age'),
#  (5.32, 'deal'),
#  (5.32, 'reason'),
#  (5.33, 'c'),
#  (5.33, 'police'),
#  (5.35, 'members'),
#  (5.35, 'months'),
#  (5.35, 'series'),
#  (5.36, 'class'),
#  (5.37, 'air'),
#  (5.37, 'friend'),
#  (5.37, 'hit'),
#  (5.37, 'playing'),
#  (5.38, 'girl'),
#  (5.39, 'history'),
#  (5.39, 'research'),
#  (5.39, 'university'),
#  (5.4, 'body'),
#  (5.4, 'control'),
#  (5.4, 'death'),
#  (5.4, 'food'),
#  (5.4, 'office'),
#  (5.41, 'half'),
#  (5.41, 'level'),
#  (5.42, 'others'),
#  (5.43, 'book'),
#  (5.43, 'friends'),
#  (5.44, 'course'),
#  (5.44, 'games'),
#  (5.45, 'president'),
#  (5.45, 'story'),
#  (5.45, 'working'),
#  (5.46, 'area'),
#  (5.46, 'law'),
#  (5.46, 'war'),
#  (5.47, 'children'),
#  (5.48, 'country'),
#  (5.48, 'season'),
#  (5.49, 'later'),
#  (5.49, 'service'),
#  (5.5, 'job'),
#  (5.5, 'side'),
#  (5.51, 'head'),
#  (5.51, 'men'),
#  (5.52, 'including'),
#  (5.52, 'music'),
#  (5.52, 'power'),
#  (5.52, 'states'),
#  (5.54, 'change'),
#  (5.54, 'point'),
#  (5.55, 'anything'),
#  (5.55, 'person'),
#  (5.56, 'business'),
#  (5.56, 'start'),
#  (5.56, 'times'),
#  (5.57, 'group'),
#  (5.6, 'company'),
#  (5.61, 'city'),
#  (5.61, 'days'),
#  (5.61, 'name'),
#  (5.62, 'number'),
#  (5.63, 'second'),
#  (5.64, 'money'),
#  (5.66, 'family'),
#  (5.67, 'team'),
#  (5.68, 'end'),
#  (5.68, 'show'),
#  (5.7, 'again'),
#  (5.71, 'place'),
#  (5.71, 'school'),
#  (5.72, 'game'),
#  (5.72, 'thing'),
#  (5.75, 'help'),
#  (5.78, 'part'),
#  (5.81, 'home'),
#  (5.82, 'man'),
#  (5.89, 'life'),
#  (5.89, 'world'),
#  (5.96, 'work'),
#  (5.96, 'year'),
#  (5.96, 'years'),
#  (5.98, 'may'),
#  (6.04, 'back'),
#  (6.11, 'him'),
#  (6.12, 'only'),
#  (6.25, 'people'),
#  (6.26, 'she'),
#  (6.29, 'time'),
#  (6.3, 'her'),
#  (6.47, 'one'),
#  (6.82, 'this'),
#  (7.27, 'in'),
#  (7.41, 'and'),
#  (7.73, 'the')]

# %%
len(ordered_nouns)
# Out:
# 703

# %%
# -> generate plot_count plots as such:
# -> for each plot, 3 high frequency and 3 low frequency nouns are chosen
# -> for each noun, the eeg data associated with each appearence is extracted, the shorter appearences are padded with their respective 
# means to match the longest appearence, then all eeg data is averaged and plotted
# NOTE: currently, the most frequent nouns are ignored due to nltk's high error rate in that range, as well as the least frequent 15, to 
# match sample counts
# -> results are saved in pos_analysis/wordfreq_statistics
task = 'TSR'
plot_channel = 51 # in device indices (a.k.a. 1-128)
plot_count = 10
pos_tags_src = 'nltk'

highfreq_colors = [(1, 0, 0), # red
                   (1, 0.33, 0), # orange 
                   (1, 1, 0)] # yellow
lowfreq_colors = [(0, 0, 0.75), # blue
                  (0, 0.75, 0), # green
                  (0.75, 0, 0.75)] # purple

df = pd.read_csv(f'{EXTRACTED_DATA_PATH}extracted_data_{task}/pos_tags/{pos_tags_src}.tsv', sep='\t', keep_default_na=False)
df = df[ (df['part_of_speech'].isin(['NN', 'NNS'])) ] [['task', 'content', 'sentence_id', 'word_idx']]

nn_df = df ['content']
nn_df = pd.unique( nn_df.apply(normalize_word) )
ordered_nouns = list(reversed(sorted( [(zipf_frequency(w, 'en'), w) for w in nn_df] )))

highfreq_nouns = [ n for freq, n in ordered_nouns[15:len(ordered_nouns)//2]]
lowfreq_nouns = [ n for freq, n in list(reversed(ordered_nouns))[15:len(ordered_nouns)//2] ]

for nidx in range(0, min(len(highfreq_nouns), len(lowfreq_nouns)), 3):
    plt.figure(figsize=(10, 6))
    for j in range(3):
        # plot highfreq
        word = highfreq_nouns[nidx+j]
        word_df = df[ df['content'].apply(lambda w : normalize_word(w)==word) ]
        word_data = helper_get_word_mean_eeg(word_df[ ['task', 'sentence_id', 'word_idx'] ])
        plt.plot([t for t in range(word_data.shape[0])], word_data[:, device_channel_to_data_channel(plot_channel)], 
                 label=f'"{word}", zipf_freq={zipf_frequency(word, "en")}', color=highfreq_colors[j]) #TODO freq
        # plot lowfreq
        word = lowfreq_nouns[nidx+j]
        word_df = df[ df['content'].apply(lambda w : normalize_word(w)==word) ]
        word_data = helper_get_word_mean_eeg(word_df[ ['task', 'sentence_id', 'word_idx'] ])
        plt.plot([t for t in range(word_data.shape[0])], word_data[:, device_channel_to_data_channel(plot_channel)], 
                 label=f'"{word}", zipf_freq={zipf_frequency(word, "en")}', color=lowfreq_colors[j]) #TODO freq
    plt.xlabel('Time (ms)')
    plt.ylabel('Amplitude (µV)')
    plt.title(f'E{plot_channel} EEG data comparing high and low frequency words')
    plt.axvline(0, color='black', linestyle='--')  # Add vertical line at 0s (stimulus onset)
    plt.legend(loc='upper right')
    if not os.path.exists(f'{EXTRACTED_DATA_PATH}extracted_data_{task}/pos_analysis/wordfreq_statistics'):
        os.makedirs(f'{EXTRACTED_DATA_PATH}extracted_data_{task}/pos_analysis/wordfreq_statistics')
    plt.savefig(f'{EXTRACTED_DATA_PATH}extracted_data_{task}/pos_analysis/wordfreq_statistics/wordfreq_comparison_plot{plot_count}.png', format='png', dpi=1200)
    plt.close()
    plot_count -= 1
    print(f'Finished plotting batch.')
    if plot_count == 0:
        break
print('Done')
# Out:
# Finished plotting batch.
# Finished plotting batch.
# Finished plotting batch.
# Finished plotting batch.
# Finished plotting batch.
# Finished plotting batch.
# Finished plotting batch.
# Finished plotting batch.
# Finished plotting batch.
# Finished plotting batch.
# Done

# %%
# print a list of words marked with a tag in tags
task = 'NR'
pos_tags_src = 'nltk'
tags = ['NN', 'NNS']
df = pd.read_csv(f'{EXTRACTED_DATA_PATH}extracted_data_{task}/pos_tags/{pos_tags_src}.tsv', sep='\t', keep_default_na=False)
list(  pd.unique(df[ df['part_of_speech'].isin(tags) ]['content'].apply(normalize_word))  )
# Out:
# ['son',
#  'philanthropic',
#  'organization',
#  'charter',
#  'welfare',
#  'success',
#  'and',
#  'investors',
#  'interest',
#  'race',
#  'cars',
#  'company',
#  'period',
#  'quadricycle',
#  'victory',
#  'driver',
#  'favorite',
#  'engineer',
#  'promotion',
#  'time',
#  'money',
#  'attention',
#  'experiments',
#  'combustion',
#  'engines',
#  'completion',
#  'vehicle',
#  'year',
#  'farm',
#  'city',
#  'parents',
#  '1826-1905',
#  'immigrants',
#  'years',
#  'wars',
#  'regime',
#  'evidence',
#  'backing',
#  'politics',
#  'part',
#  'statements',
#  'representative',
#  'daughter-in-law',
#  'funds',
#  'movement',
#  'sources',
#  'concept',
#  'development',
#  'employees',
#  'associate',
#  'spot',
#  'widow',
#  'stock',
#  'position',
#  'home',
#  'apprentice',
#  'machinist',
#  'actor',
#  'brothers',
#  'quarters',
#  'quarter',
#  'descent',
#  'movies',
#  'job',
#  'busboy',
#  'disco',
#  'candidate',
#  'office',
#  'particular',
#  'hosts',
#  'show',
#  'times',
#  'appearances',
#  'movie',
#  'version',
#  "children's",
#  'series',
#  'appearance',
#  'scoutmaster',
#  'pedophile',
#  'shirt',
#  'mouth',
#  'neck',
#  'may',
#  'singer',
#  'actress',
#  'she',
#  'recordings',
#  'band',
#  'children',
#  'nephew',
#  'entertainers',
#  'sisters',
#  'radio',
#  'station',
#  'singers',
#  'miles',
#  'grandmother',
#  'number',
#  'end',
#  'again',
#  'duet',
#  'columnist',
#  'administration',
#  'marriage',
#  'initiative',
#  'program',
#  'readers',
#  'c',
#  'soldier',
#  'blacksmith',
#  'militia',
#  'soldiers',
#  'family',
#  'area',
#  'presidents',
#  'grandfather',
#  'president',
#  'preacher',
#  'church',
#  'discussion',
#  'group',
#  'pioneer',
#  'power',
#  'influence',
#  "community's",
#  'men',
#  'trial',
#  'heretic',
#  'followers',
#  'football',
#  'insiders',
#  'playoffs',
#  'playoff',
#  'game',
#  'games',
#  'record',
#  'honor',
#  'passer',
#  'rating',
#  'career',
#  'title',
#  'interceptions',
#  'loss',
#  'numbers',
#  'season',
#  'touchdowns',
#  'second',
#  'voting',
#  'mother',
#  'death',
#  'role',
#  'life',
#  "bachelor's",
#  'degree',
#  'history',
#  'taylor',
#  'citizenship',
#  'consort',
#  'daughter',
#  'condition',
#  'stupor',
#  'symptoms',
#  'self-mutilation',
#  'hallucinations',
#  '1760s',
#  'affair',
#  'portrait',
#  'comparisons',
#  'this',
#  'arrest',
#  'warrant',
#  'indifference',
#  'pressure',
#  'dissolved',
#  'exile',
#  'days',
#  'cancer',
#  'film',
#  'director',
#  'later',
#  're-make',
#  'wife',
#  'divorced',
#  'portrayal',
#  'name',
#  'father',
#  'television',
#  'sitcom',
#  'attorney',
#  'soap',
#  'opera',
#  'lightning',
#  'campaign',
#  'politician',
#  'capital',
#  'punishment',
#  'school',
#  'university',
#  'education',
#  'biography',
#  'talks',
#  'experiences',
#  'battle',
#  'war',
#  'injuries',
#  'boy',
#  'soda',
#  'jerk',
#  'drug',
#  'store',
#  'nomination',
#  'bid',
#  'contest',
#  'issues',
#  'point',
#  'newscaster',
#  'conversation',
#  'anything',
#  'chairman',
#  'studies',
#  'start',
#  'jazz',
#  'trumpeter',
#  'cornetist',
#  'commentator',
#  'election',
#  'desire',
#  'wealth',
#  'grows',
#  'values',
#  'greed',
#  'society',
#  'crumbles',
#  'population',
#  'centers',
#  'west',
#  'world',
#  'trade',
#  'center',
#  'strokes',
#  'lung',
#  'age',
#  'brother',
#  'actors',
#  'intervened',
#  'operation',
#  'appendicitis',
#  'husband',
#  'millionaire',
#  'words',
#  'fellow',
#  'thing',
#  'memoirs',
#  'body',
#  'funeral',
#  'corpse',
#  'chair',
#  'bar',
#  'accounts',
#  'tale',
#  'substitute',
#  'place',
#  'amd',
#  'aid',
#  'aunt',
#  'researcher',
#  'reporter',
#  'ship',
#  'sea',
#  'burial',
#  'bandleader',
#  'composer',
#  'business',
#  'difficulties',
#  'designs',
#  'production',
#  'lieutenant',
#  'engineers',
#  'month',
#  'brevet',
#  'expedition',
#  'areas',
#  'purpose',
#  'voyage',
#  'rivers',
#  'summer',
#  'explorer',
#  'feature',
#  'hair',
#  'beehive',
#  'blue',
#  "she's",
#  'mule',
#  'seventeen',
#  'exceptions',
#  'rage',
#  'creator',
#  'flight',
#  'attendant',
#  'air',
#  'steward',
#  'members',
#  'except',
#  'course',
#  'voices',
#  'sarcastic',
#  'snarky',
#  'demeanours',
#  'none',
#  'approves',
#  'behaviour',
#  'clumsy',
#  'insensitive',
#  'dads',
#  'template',
#  'fathers',
#  'deal',
#  'friends',
#  'bartender',
#  'occasions',
#  'months',
#  'sniper',
#  'fallaciously',
#  'contract',
#  'roles',
#  'cremated',
#  'ashes',
#  'accent',
#  'best-known',
#  'writers',
#  'work',
#  'languages',
#  'book',
#  'banker',
#  'insurance',
#  'deaths',
#  'close-knit',
#  'music',
#  'generations',
#  'musicians',
#  'disease',
#  'courage',
#  'determination',
#  'defense',
#  'clutch',
#  'shooter',
#  'range',
#  'throw',
#  'nickname',
#  'afterwards',
#  'major',
#  'deed',
#  'poet',
#  'writer',
#  'law',
#  'firm',
#  'client',
#  'imprint',
#  'contemporary',
#  'reissues',
#  'label',
#  'conduit',
#  'alliance',
#  'treaty',
#  'restoration',
#  'independence',
#  'accession',
#  'throne',
#  'dowry',
#  'control',
#  'choice',
#  'queen',
#  'religion',
#  'service',
#  'reputation',
#  'womaniser',
#  'birth',
#  'heir',
#  'one',
#  'mistresses',
#  'respect',
#  'her',
#  'reign',
#  'physician',
#  'medicine',
#  'botany',
#  'poetry',
#  'introduced',
#  'custom',
#  'tea',
#  'people',
#  'borough',
#  'change',
#  'bureaucracy',
#  'form',
#  'only',
#  'class',
#  'academy',
#  'fearless',
#  'expert',
#  'horseman',
#  'drank',
#  'cigars',
#  'story',
#  'throat',
#  'tanner',
#  'member',
#  'icon',
#  'liberalism',
#  'person',
#  'country',
#  'instances',
#  'careers',
#  'beliefs',
#  'surrendered',
#  'twice',
#  'rest',
#  'supporter',
#  'requests',
#  'autobiography',
#  'in',
#  'sleepless',
#  'nights',
#  'immigration',
#  'presidency',
#  'policies',
#  'policy',
#  'movements',
#  'combat',
#  'duty',
#  'astigmatism',
#  'landslide',
#  'states',
#  'percent',
#  'vote',
#  'gift',
#  'acting',
#  'announcer',
#  'affiliate',
#  'baseball',
#  'bare',
#  'outlines',
#  'ticker',
#  'imagination',
#  'gifts',
#  'inning',
#  'wire',
#  'dead',
#  'play-by-play',
#  'hitters',
#  'teams',
#  'pitches',
#  'restored',
#  'terrorists',
#  'list',
#  'demands',
#  'distribution',
#  'food',
#  'poor',
#  'outbreak',
#  'botulism',
#  'prize',
#  'research',
#  'synapses',
#  'findings',
#  'pair',
#  'ion',
#  'channels',
#  'decades',
#  'team',
#  'junior',
#  'seasons',
#  'tv',
#  'journalist',
#  'niece',
#  'goals',
#  'assists',
#  'round',
#  'camp',
#  'sounders',
#  'lifetime',
#  'authors',
#  'language',
#  'style',
#  'novel',
#  'natives',
#  'province',
#  'quebecers',
#  'generation',
#  'emigration',
#  'employment',
#  'six',
#  'mayor',
#  'elder',
#  'screen',
#  'contribution',
#  'industry',
#  'star',
#  'man',
#  'decision',
#  'fate',
#  'unknown',
#  'offense',
#  'whipping',
#  'imprisonment',
#  'printer',
#  'shops',
#  'town',
#  'prospects',
#  'weeks',
#  'help',
#  'merchant',
#  'shopkeeper',
#  'bookkeeper',
#  'unit',
#  'charge',
#  'franklin',
#  'fr',
#  'statcoulomb',
#  'miller',
#  'schoolteacher',
#  'servant',
#  'half',
#  'including',
#  'the',
#  'identity',
#  'responsibility',
#  'child',
#  'reason',
#  'residence',
#  'chandler',
#  'maker',
#  'candles',
#  'schooling',
#  'printing',
#  'pseudonym',
#  'silence',
#  'author',
#  'correspondent',
#  'apprenticeship',
#  'permission',
#  'fugitive',
#  'commissioned',
#  'theater',
#  'captain',
#  'intelligence',
#  'staff',
#  'admiration',
#  'publisher',
#  'magazine',
#  'decade',
#  'security',
#  'account',
#  'questions',
#  'adequacy',
#  'capabilities',
#  'colleages',
#  'him',
#  'heart',
#  'failure',
#  'chiefly',
#  'diabetes',
#  'sister',
#  'leader',
#  've',
#  'transport',
#  'hit',
#  'release',
#  'interests',
#  'skills',
#  'diffraction',
#  'manager',
#  'police',
#  '100',
#  'conviction',
#  'authorities',
#  'convictions',
#  'offence',
#  'ancestors',
#  'side',
#  'boarder',
#  'aides',
#  'confidantes',
#  'lives',
#  'semesters',
#  'difficulty',
#  'books',
#  'articles',
#  'co-host',
#  'speaker',
#  'science',
#  'chief',
#  'figures',
#  'investigation',
#  'felony',
#  'counts',
#  'secretary',
#  'advisor',
#  'resignation',
#  'confirmation',
#  'officer',
#  'friend',
#  'collaborator',
#  'cancelled',
#  'handyman',
#  'debut',
#  'adaptation',
#  'producer',
#  'experience',
#  'comedy',
#  '1947',
#  'acclaim',
#  'cast',
#  'victim',
#  'abuse',
#  'childhood',
#  'arm',
#  'glass',
#  'pane',
#  'doctors',
#  'injury',
#  'forces',
#  'yank',
#  '1942',
#  'snobby',
#  'picture',
#  'smash',
#  'performance',
#  'page',
#  'albums',
#  'catchphrase',
#  'cash',
#  'fame',
#  'college',
#  'player',
#  'coach',
#  'teammate',
#  'wagon',
#  "greasin's",
#  'century',
#  'example',
#  'belief',
#  'ability',
#  'creation',
#  'acts',
#  'decorations',
#  'edition',
#  'nation',
#  'involvement',
#  'bill',
#  'families',
#  'void',
#  'hopes',
#  'seat',
#  'district',
#  'opponent',
#  'margin',
#  'spring',
#  'back',
#  'commands',
#  'rank',
#  'patrol',
#  'torpedo',
#  'boat',
#  'mathematician',
#  'leaders',
#  'mathematics',
#  '1911-1996',
#  'playing',
#  'others',
#  'educator',
#  'theory',
#  'workshop',
#  'entry',
#  'level',
#  'division',
#  'estate',
#  'immigrant',
#  'elementary',
#  'poverty',
#  'working',
#  'partner',
#  'activist',
#  'head',
#  'governor',
#  'voters',
#  'boarding',
#  'urging',
#  'devout',
#  'grades',
#  'speeches',
#  'speaking',
#  'residents',
#  'bank',
#  'summers',
#  'holidays',
#  'student',
#  'exchange',
#  'motorcycle',
#  'girl',
#  'oil',
#  'drilling']

# %%
tagmap = {
    'noun-common': ['NN', 'NNS'],
    'noun-proper': ['NNP', 'NNPS'],
    'adjective': ['JJ', 'JJR', 'JJS'],
    'pronoun': ['PRP', 'PRP$'],
    'adverb': ['RB', 'RBR', 'RBS'],
    'verb': ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']
}

# %%
# generate topomaps of the activations of each part of speech in tagmap
# only word instances win TRT>=min_trt are accepted
# shorter instances are padded (according to padding) and averaged together
# afterwards the eeg means of the instances are padded to match the longest and averaged again
# Results are saved in the pos_analysis/topomaps folder

task = 'TSR'
pos_tags_src = 'nltk'
min_trt = 500
padding = 'mean'

tagmap = {
    'noun-common': ['NN', 'NNS'],
    'noun-proper': ['NNP', 'NNPS'],
    'adjective': ['JJ', 'JJR', 'JJS'],
    'pronoun': ['PRP', 'PRP$'],
    'adverb': ['RB', 'RBR', 'RBS'],
    'verb': ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']
}

if not os.path.exists(f'{EXTRACTED_DATA_PATH}extracted_data_{task}/pos_analysis/topomaps'):
    os.makedirs(f'{EXTRACTED_DATA_PATH}extracted_data_{task}/pos_analysis/topomaps')

pos_df = pd.read_csv(f'{EXTRACTED_DATA_PATH}extracted_data_{task}/pos_tags/{pos_tags_src}.tsv', sep='\t', keep_default_na=False, na_values=[''])
full_df = pd.read_csv(f'{EXTRACTED_DATA_PATH}extracted_data_{task}/data.tsv', sep='\t', keep_default_na=False, na_values=[''])
full_df['TRT'] = full_df['TRT'].astype(float)

def helper_process_pos_df_row(row):
    curr_full_df = full_df[(full_df['TRT']>=min_trt) & (full_df['sentence_id']==row['sentence_id']) & (full_df['word_idx']==row['word_idx'])]
    eeg_mean = helper_get_word_mean_eeg( curr_full_df[['task', 'sentence_id', 'word_idx']], padding=padding )
    return eeg_mean

for pos in tagmap.keys():
    print(f'Potting for {pos}...')
    curr_pos_df = pos_df[ pos_df['part_of_speech'].isin(tagmap[pos]) ]
    instance_means = curr_pos_df.apply(helper_process_pos_df_row, axis=1).dropna()
    maxlen = instance_means.apply(lambda x: len(x)).max()
    padded_instance_means = instance_means.apply(eeg_data_pad_to_len, args=(maxlen, padding)).to_numpy()
    pos_mean = np.mean(padded_instance_means, axis=0)
    evoked = get_evoked_for_eeg_data(pos_mean, frequency=1000) # TODO freq
    fig = evoked.plot_topomap(times='peaks', show=False)
    fig.savefig(f'{EXTRACTED_DATA_PATH}extracted_data_{task}/pos_analysis/topomaps/{pos}_topomap_{padding}.png', format='png', dpi=1200)
    plt.close()
    print(f'Finished plotting for {pos}')
print('Done')
# Out:
# Potting for noun-common...
# Finished plotting for noun-common
# Potting for noun-proper...
# Finished plotting for noun-proper
# Potting for adjective...
# Finished plotting for adjective
# Potting for pronoun...
# Finished plotting for pronoun
# Potting for adverb...
# Finished plotting for adverb
# Potting for verb...
# Finished plotting for verb
# Done

# %%
# generate spectral density plots of the activations of each part of speech in tagmap
# only word instances win TRT>=min_trt are accepted
# shorter instances are padded (according to padding) and averaged together
# afterwards the eeg means of the instances are padded to match the longest and averaged again
# Results are saved in the pos_analysis/topomaps folder

task = 'TSR'
pos_tags_src = 'nltk'
min_trt = 200
padding = 'mean'

tagmap = {
    'noun-common': ['NN', 'NNS'],
    'noun-proper': ['NNP', 'NNPS'],
    'adjective': ['JJ', 'JJR', 'JJS'],
    'pronoun': ['PRP', 'PRP$'],
    'adverb': ['RB', 'RBR', 'RBS'],
    'verb': ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']
}

if not os.path.exists(f'{EXTRACTED_DATA_PATH}extracted_data_{task}/pos_analysis/spectrography/mintrt{min_trt}'):
    os.makedirs(f'{EXTRACTED_DATA_PATH}extracted_data_{task}/pos_analysis/spectrography/mintrt{min_trt}')

pos_df = pd.read_csv(f'{EXTRACTED_DATA_PATH}extracted_data_{task}/pos_tags/{pos_tags_src}.tsv', sep='\t', keep_default_na=False, na_values=[''])
full_df = pd.read_csv(f'{EXTRACTED_DATA_PATH}extracted_data_{task}/data.tsv', sep='\t', keep_default_na=False, na_values=[''])
full_df['TRT'] = full_df['TRT'].astype(float)

def helper_process_pos_df_row(row):
    curr_full_df = full_df[(full_df['TRT']>=min_trt) & (full_df['sentence_id']==row['sentence_id']) & (full_df['word_idx']==row['word_idx'])]
    eeg_mean = helper_get_word_mean_eeg( curr_full_df[['task', 'sentence_id', 'word_idx']], padding=padding )
    return eeg_mean

for pos in tagmap.keys():
    print(f'Potting for {pos}...')
    curr_pos_df = pos_df[ pos_df['part_of_speech'].isin(tagmap[pos]) ]
    instance_means = curr_pos_df.apply(helper_process_pos_df_row, axis=1).dropna()
    maxlen = instance_means.apply(lambda x: len(x)).max()
    padded_instance_means = instance_means.apply(eeg_data_pad_to_len, args=(maxlen, padding)).to_numpy()
    pos_mean = np.mean(padded_instance_means, axis=0)
    evoked = get_evoked_for_eeg_data(pos_mean, frequency=1000) # TODO freq
    spectrum = evoked.compute_psd(n_jobs=3)
    fig = spectrum.plot(exclude='bads', show=False)
    fig.savefig(f'{EXTRACTED_DATA_PATH}extracted_data_{task}/pos_analysis/spectrography/mintrt{min_trt}/{pos}_psd_{padding}.png', format='png', dpi=1200)
    plt.close()
    print(f'Finished plotting for {pos}')
print('Done')
# Out:
# Potting for noun-common...
#     Using multitaper spectrum estimation with 7 DPSS windows
# Plotting power spectral density (dB=True).
# Finished plotting for noun-common
# Potting for noun-proper...
#     Using multitaper spectrum estimation with 7 DPSS windows
# Plotting power spectral density (dB=True).
# Finished plotting for noun-proper
# Potting for adjective...
#     Using multitaper spectrum estimation with 7 DPSS windows
# Plotting power spectral density (dB=True).
# Finished plotting for adjective
# Potting for pronoun...
#     Using multitaper spectrum estimation with 7 DPSS windows
# Plotting power spectral density (dB=True).
# Finished plotting for pronoun
# Potting for adverb...
#     Using multitaper spectrum estimation with 7 DPSS windows
# Plotting power spectral density (dB=True).
# Finished plotting for adverb
# Potting for verb...
#     Using multitaper spectrum estimation with 7 DPSS windows
# Plotting power spectral density (dB=True).
# Finished plotting for verb
# Done

# %%
task = 'TSR'
full_df = pd.read_csv(f'{EXTRACTED_DATA_PATH}extracted_data_{task}/data.tsv', sep='\t', keep_default_na=False, na_values=[''])
full_df['TRT'] = full_df['TRT'].astype(float)
full_df['TRT'].max()
# Out:
# np.float64(3837.0)

# %%
len(full_df)
# Out:
# 143831

# %%
full_df[ [i%2==0 for i in range(143831)] ]
# Out:
#                                                  sentence  sentence_id  \
# 0       He was also the unsuccessful Republican nomine...            0
# 2       He was also the unsuccessful Republican nomine...            0
# 4       He was also the unsuccessful Republican nomine...            0
# 6       He was also the unsuccessful Republican nomine...            0
# 8       He was also the unsuccessful Republican nomine...            0
# ...                                                   ...          ...
# 143822  In 1999 Bush cofounded a educational-software ...          389
# 143824  In 1999 Bush cofounded a educational-software ...          389
# 143826  In 1999 Bush cofounded a educational-software ...          389
# 143828  In 1999 Bush cofounded a educational-software ...          389
# 143830  In 1999 Bush cofounded a educational-software ...          389
#
#        subject task       content  word_idx     GD    TRT    FFD    SFD  \
# 0          YMD  TSR            He         0    NaN    NaN    NaN    NaN
# 2          YMD  TSR          also         2    NaN    NaN    NaN    NaN
# 4          YMD  TSR  unsuccessful         4  112.0  209.0  112.0    NaN
# 6          YMD  TSR       nominee         6  251.0  251.0  106.0    NaN
# 8          YMD  TSR     President         8  170.0  298.0   51.0    NaN
# ...        ...  ...           ...       ...    ...    ...    ...    ...
# 143822     YAK  TSR         types        16    NaN    NaN    NaN    NaN
# 143824     YAK  TSR       content        18  154.0  154.0  154.0  154.0
# 143826     YAK  TSR        appeal        20   84.0   84.0   84.0   84.0
# 143828     YAK  TSR      multiple        22  121.0  121.0  121.0  121.0
# 143830     YAK  TSR       styles.        24  125.0  125.0  125.0  125.0
#
#           GPT  nFix  reading_order  first_fixation_time
# 0         NaN   NaN            NaN                  NaN
# 2         NaN   NaN            NaN                  NaN
# 4       112.0   2.0            2.0                179.0
# 6       251.0   2.0            4.0                587.0
# 8       170.0   3.0            5.0                778.0
# ...       ...   ...            ...                  ...
# 143822    NaN   NaN            NaN                  NaN
# 143824  154.0   1.0           13.0               2604.0
# 143826   84.0   1.0           14.0               2745.0
# 143828  121.0   1.0           15.0               2899.0
# 143830  125.0   1.0           17.0               3104.0
#
# [71916 rows x 14 columns]
